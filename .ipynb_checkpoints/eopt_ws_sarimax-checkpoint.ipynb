# %% [markdown]
# # Electrisity Output and Wind Speed Model

# %% [markdown]
# ## SRIMAX

# %% [markdown]
# ## Data Loading and exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statsmodels.api as sm
from tqdm import tqdm

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.tsa.statespace.sarimax import SARIMAX

from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
## load data
df = pd.read_excel('data/Wind_data.xlsx', index_col='DATETIME', sheet_name=[0, 1])
df_train, df_test = df.get(0), df.get(1)
print(f'Train data dim: {df_train.shape}')
print(f'Test data dim: {df_test.shape}')
# Out:
# Train data dim: (3635, 113)
# Test data dim: (93, 113)

# %%
df_train.head()
# Out:
#                            CF  WS_1133733  WS_1156770  WS_1156968  WS_1182195  \
# DATETIME
# 2019-08-07 00:00:00  0.652524       10.35        8.99        4.57        9.69
# 2019-08-07 01:00:00  0.605852        9.70        8.28        5.78        9.10
# 2019-08-07 02:00:00  0.564094        9.04        7.39        6.21        8.98
# 2019-08-07 03:00:00  0.532721        8.78        7.49        6.43        8.84
# 2019-08-07 04:00:00  0.495608        8.23        6.88        6.81        8.52
#
#                      WS_1193865  WS_1321569  WS_1324653  WS_1358699  \
# DATETIME
# 2019-08-07 00:00:00        8.90        2.90        5.74        1.16
# 2019-08-07 01:00:00        7.98        2.23        3.46        0.97
# 2019-08-07 02:00:00        7.78        1.98        2.62        0.92
# 2019-08-07 03:00:00        7.82        1.33        2.43        0.68
# 2019-08-07 04:00:00        6.65        1.64        2.45        0.59
#
#                      WS_1366338  ...  WS_78208  WS_811655  WS_839753  \
# DATETIME                         ...
# 2019-08-07 00:00:00        8.81  ...     11.12       6.79       9.31
# 2019-08-07 01:00:00        7.75  ...     10.47       6.40       9.50
# 2019-08-07 02:00:00        7.55  ...     10.10       6.23       9.46
# 2019-08-07 03:00:00        7.53  ...      9.67       6.01       9.45
# 2019-08-07 04:00:00        6.40  ...      9.24       5.83       9.30
#
#                      WS_875373  WS_883683  WS_883699  WS_914573  WS_918665  \
# DATETIME
# 2019-08-07 00:00:00      11.63      10.72      10.55      11.41      10.77
# 2019-08-07 01:00:00      11.10      11.02       9.91      11.16      10.98
# 2019-08-07 02:00:00      10.74      11.19       9.52      11.00      11.10
# 2019-08-07 03:00:00      10.65      11.27       9.11      10.93      11.18
# 2019-08-07 04:00:00       9.78      10.85       8.64      10.69      10.83
#
#                      WS_920775  WS_921049
# DATETIME
# 2019-08-07 00:00:00      10.17       9.24
# 2019-08-07 01:00:00      10.16       9.09
# 2019-08-07 02:00:00      10.04       9.04
# 2019-08-07 03:00:00      10.20       8.89
# 2019-08-07 04:00:00       9.88       8.67
#
# [5 rows x 113 columns]

# %%
print(df_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3635 entries, 2019-08-07 00:00:00 to 2020-01-07 23:00:00
# Columns: 113 entries, CF to WS_921049
# dtypes: float64(113)
# memory usage: 3.2 MB
# None

# %%
df_train.describe()
# Out:
#                 CF   WS_1133733   WS_1156770   WS_1156968   WS_1182195  \
# count  3635.000000  3635.000000  3635.000000  3635.000000  3635.000000
# mean      0.186114     4.532563     3.943094     5.124113     5.118909
# std       0.165140     2.790853     2.371923     2.712505     3.213767
# min       0.003551     0.590000     0.490000     0.680000     0.460000
# 25%       0.043264     2.230000     2.050000     2.870000     2.790000
# 50%       0.130778     3.660000     3.220000     4.780000     4.490000
# 75%       0.299374     6.580000     5.500000     6.860000     6.560000
# max       0.733128    14.660000    13.130000    14.640000    23.040000
#
#         WS_1193865   WS_1321569   WS_1324653   WS_1358699   WS_1366338  ...  \
# count  3635.000000  3635.000000  3635.000000  3635.000000  3635.000000  ...
# mean      5.558190     2.524281     3.927272     3.388721     5.787298  ...
# std       2.691479     1.655931     2.398751     2.834749     2.834219  ...
# min       0.530000     0.500000     0.310000     0.240000     0.570000  ...
# 25%       3.310000     1.490000     1.840000     1.350000     3.410000  ...
# 50%       5.360000     2.010000     3.340000     2.460000     5.630000  ...
# 75%       7.660000     2.980000     5.770000     4.400000     7.970000  ...
# max      17.430000    13.200000    11.810000    19.150000    17.090000  ...
#
#           WS_78208    WS_811655    WS_839753    WS_875373    WS_883683  \
# count  3635.000000  3635.000000  3635.000000  3635.000000  3635.000000
# mean      5.126252     4.689553     5.455680     4.789538     6.083490
# std       2.988879     2.483077     3.005286     2.563520     3.387885
# min       0.690000     0.420000     0.410000     0.530000     0.640000
# 25%       2.620000     2.830000     3.090000     2.600000     3.370000
# 50%       4.420000     4.300000     4.910000     4.430000     5.430000
# 75%       7.280000     6.070000     7.275000     6.870000     8.245000
# max      15.470000    15.780000    16.710000    13.530000    19.800000
#
#          WS_883699    WS_914573    WS_918665    WS_920775    WS_921049
# count  3635.000000  3635.000000  3635.000000  3635.000000  3635.000000
# mean      4.860514     5.756882     5.958355     5.699761     5.435894
# std       2.961514     3.496837     3.318751     3.143495     2.796631
# min       0.650000     0.740000     0.700000     0.490000     0.560000
# 25%       2.490000     3.130000     3.310000     3.240000     3.215000
# 50%       3.940000     5.050000     5.280000     5.110000     5.110000
# 75%       6.810000     7.740000     8.060000     7.635000     7.110000
# max      15.990000    22.660000    18.910000    16.640000    18.080000
#
# [8 rows x 113 columns]

# %%
print("Check number of missing values in train: ", df_train.isnull().sum().sum())
# Out:
# Check number of missing values in train:  0

# %%
df_train.CF.plot(figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATETIME'>

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3,1, figsize=(12,8))
plot_acf(df_train['CF'],lags=27, zero=False, ax=ax1)
plot_acf(df_train['CF'].diff().dropna(),lags=27, zero=False, ax=ax2)
plot_acf(df_train['CF'].diff().dropna().diff().dropna(),lags=27, zero=False, ax=ax3)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2,1, figsize=(12,8))
plot_pacf(df_train['CF'],lags=27, zero=False, ax=ax1)
plot_pacf(df_train['CF'].diff(1).dropna(),lags=27, zero=False, ax=ax2)
plt.show()
# Out:
# /Users/steven/opt/anaconda3/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# /Users/steven/opt/anaconda3/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
def obtain_adf_kpss_results(timeseries, max_d):
    """ Build dataframe with ADF statistics and p-value for time series after applying difference on time series
    
    Args:
        time_series (df): Dataframe of univariate time series  
        max_d (int): Max value of how many times apply difference
        
    Returns:
        Dataframe showing values of ADF statistics and p when applying ADF test after applying d times 
        differencing on a time-series.
    
    """
    
    results=[]

    for idx in range(max_d):
        adf_result = adfuller(timeseries, autolag='AIC')
        kpss_result = kpss(timeseries, regression='c', nlags="auto")
        timeseries = timeseries.diff().dropna()
        if adf_result[1] <=0.05:
            adf_stationary = True
        else:
            adf_stationary = False
        if kpss_result[1] <=0.05:
            kpss_stationary = False
        else:
            kpss_stationary = True
            
        stationary = adf_stationary & kpss_stationary
            
        results.append((idx,adf_result[1], kpss_result[1],adf_stationary,kpss_stationary, stationary))
    
    # Construct DataFrame 
    results_df = pd.DataFrame(results, columns=['d','adf_stats','p-value', 'is_adf_stationary','is_kpss_stationary','is_stationary' ])
    
    return results_df


def adf_test(timeseries):
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)


def kpss_test(timeseries):
    print ('Results of KPSS Test:')
    kpsstest = kpss(timeseries, regression='c', nlags="auto")
    kpss_output = pd.Series(kpsstest[0:3], index=['Test Statistic','p-value','Lags Used'])
    for key,value in kpsstest[3].items():
        kpss_output['Critical Value (%s)'%key] = value
    print (kpss_output)
    
obtain_adf_kpss_results(df_train['CF'],3)

# print(f'The above table indicates d == 1 is a good choice')
# Out:
# /Users/steven/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# /Users/steven/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# /Users/steven/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
#    d     adf_stats  p-value  is_adf_stationary  is_kpss_stationary  \
# 0  0  4.289205e-14     0.01               True               False
# 1  1  4.822957e-24     0.10               True                True
# 2  2  0.000000e+00     0.10               True                True
#
#    is_stationary
# 0          False
# 1           True
# 2           True

# %% [markdown]
# #### The above table indicates d==1 is a good choice

# %% [markdown]
# ## Feature Engineering: Identify significant variables

# %%
# Compute correlation between variables and target
# In this correlation map, light color means lower covariance of two variables.
# We can not manually decide which features are salent, it looks like most of the features are relavant. 
# As a result, some numeriacal feature selection algorithms can be adopted.

import seaborn as sns
data = df_train
data.corr(method='pearson')
plt.subplots(figsize=(15, 10))
sns.heatmap(data.corr(), cmap="PiYG")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Data Preprocessing

# %%
def pre_process(data,drop_time=False):
  
    # data['hour'] = data['DATETIME'].dt.hour
    # data['month'] = data['DATETIME'].dt.month
    # data['day'] = data['DATETIME'].dt.day
    if not drop_time:
        data = data.set_index('DATETIME')
    else:
        data = data.drop(['DATETIME'], axis=1)   
    
    return(data)

# %%
data = df_train.reset_index(drop=True)

print(data.head())
# Out:
#          CF  WS_1133733  WS_1156770  WS_1156968  WS_1182195  WS_1193865  \
# 0  0.652524       10.35        8.99        4.57        9.69        8.90
# 1  0.605852        9.70        8.28        5.78        9.10        7.98
# 2  0.564094        9.04        7.39        6.21        8.98        7.78
# 3  0.532721        8.78        7.49        6.43        8.84        7.82
# 4  0.495608        8.23        6.88        6.81        8.52        6.65
#
#    WS_1321569  WS_1324653  WS_1358699  WS_1366338  ...  WS_78208  WS_811655  \
# 0        2.90        5.74        1.16        8.81  ...     11.12       6.79
# 1        2.23        3.46        0.97        7.75  ...     10.47       6.40
# 2        1.98        2.62        0.92        7.55  ...     10.10       6.23
# 3        1.33        2.43        0.68        7.53  ...      9.67       6.01
# 4        1.64        2.45        0.59        6.40  ...      9.24       5.83
#
#    WS_839753  WS_875373  WS_883683  WS_883699  WS_914573  WS_918665  \
# 0       9.31      11.63      10.72      10.55      11.41      10.77
# 1       9.50      11.10      11.02       9.91      11.16      10.98
# 2       9.46      10.74      11.19       9.52      11.00      11.10
# 3       9.45      10.65      11.27       9.11      10.93      11.18
# 4       9.30       9.78      10.85       8.64      10.69      10.83
#
#    WS_920775  WS_921049
# 0      10.17       9.24
# 1      10.16       9.09
# 2      10.04       9.04
# 3      10.20       8.89
# 4       9.88       8.67
#
# [5 rows x 113 columns]

# %% [markdown]
# ## Data Splitting

# %%
# split train and validation 
Y = data[['CF']]
X = data.drop(['CF'], axis=1)
X = sm.add_constant(X)
# x_train, x_val,y_train, y_val = X[:-92], X[-92:], Y[:-92], Y[-92:]
x_train, x_val,y_train, y_val = train_test_split(X, Y, test_size=0.2, shuffle=False)
x, y, x_vals, y_vals = x_train.values, y_train.values, x_val.values, y_val.values
print(x_train.shape)
print(y_train.shape)
# Out:
# (2908, 113)
# (2908, 1)

# %%
print(x_val.shape)
print(y_val.shape)
# Out:
# (727, 113)
# (727, 1)

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Grid search to find the best model parameters

# %%
# ## outputs corresponding p,q,P,Q AIC, BIC and corresponding MAE, will select best MAE as our model parameters
# ## it takes days to run this grid search on my laptop
# %%time
# res=[]

# for p in range(3, 5):
#     for q in range(1, 6):
#         for P in range(3):
#             for Q in range(3):
#                 print(f'p, q, P, Q:{p,q,P,Q}')
#                 model = SARIMAX(y_train, exog = x_train, order=(p,1,q), seasonal_order=(P,1,Q,24)) #because adf test showed that d=1, seasonal period = 24
#                 output = model.fit()
#                 forecast = output.forecast(steps = len(x_val),exog = x_val)
#                 y_hat, y_validation = forecast.values, y_val.values
#                 mae = mean_absolute_error(y_validation, y_hat)

#                 res.append((p, 1, q, P, 1, Q, output.aic, output.bic, mae))
        
        

# res_sorted = pd.DataFrame(res, columns=['p', 'd', 'q', 'P', 'D', 'Q', 'AIC','BIC', 'MAE'])
# Out:
# p, q, P, Q:(3, 1, 0, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 1, 0, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 1, 0, 2)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 1, 1, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 1, 1, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 1, 1, 2)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 1, 2, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 1, 2, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 1, 2, 2)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 2, 0, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 2, 0, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 2, 0, 2)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 2, 1, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 2, 1, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 2, 1, 2)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 2, 2, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 2, 2, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 2, 2, 2)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 3, 0, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 3, 0, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 3, 0, 2)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 3, 1, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 3, 1, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 3, 1, 2)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 3, 2, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 3, 2, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 3, 2, 2)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 4, 0, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 4, 0, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 4, 0, 2)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 4, 1, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 4, 1, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 4, 1, 2)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 4, 2, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 4, 2, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 4, 2, 2)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 5, 0, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 5, 0, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 5, 0, 2)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 5, 1, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 5, 1, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 5, 1, 2)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 5, 2, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 5, 2, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(3, 5, 2, 2)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(4, 1, 0, 0)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# p, q, P, Q:(4, 1, 0, 1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:9
#
# File C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:704, in MLEModel.fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     702         flags['hessian_method'] = optim_hessian
#     703     fargs = (flags,)
# --> 704     mlefit = super(MLEModel, self).fit(start_params, method=method,
#     705                                        fargs=fargs,
#     706                                        maxiter=maxiter,
#     707                                        full_output=full_output,
#     708                                        disp=disp, callback=callback,
#     709                                        skip_hessian=True, **kwargs)
#     711 # Just return the fitted parameters if requested
#     712 if return_params:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:566, in LikelihoodModel.fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     563     del kwargs["use_t"]
#     565 optimizer = Optimizer()
# --> 566 xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     567                                                fargs, kwargs,
#     568                                                hessian=hess,
#     569                                                method=method,
#     570                                                disp=disp,
#     571                                                maxiter=maxiter,
#     572                                                callback=callback,
#     573                                                retall=retall,
#     574                                                full_output=full_output)
#     575 # Restore cov_type, cov_kwds and use_t
#     576 optim_settings.update(kwds)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\optimizer.py:242, in Optimizer._fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     239     fit_funcs.update(extra_fit_funcs)
#     241 func = fit_funcs[method]
# --> 242 xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     243                      disp=disp, maxiter=maxiter, callback=callback,
#     244                      retall=retall, full_output=full_output,
#     245                      hess=hessian)
#     247 optim_settings = {'optimizer': method, 'start_params': start_params,
#     248                   'maxiter': maxiter, 'full_output': full_output,
#     249                   'disp': disp, 'fargs': fargs, 'callback': callback,
#     250                   'retall': retall, "extra_fit_funcs": extra_fit_funcs}
#     251 optim_settings.update(kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\optimizer.py:659, in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     656 elif approx_grad:
#     657     func = f
# --> 659 retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     660                                  callback=callback, args=fargs,
#     661                                  bounds=bounds, disp=disp,
#     662                                  **extra_kwargs)
#     664 if full_output:
#     665     xopt, fopt, d = retvals
#
# File C:\ProgramData\anaconda3\Lib\site-packages\scipy\optimize\_lbfgsb_py.py:199, in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     187 callback = _wrap_callback(callback)
#     188 opts = {'disp': disp,
#     189         'iprint': iprint,
#     190         'maxcor': m,
#    (...)
#     196         'callback': callback,
#     197         'maxls': maxls}
# --> 199 res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     200                        **opts)
#     201 d = {'grad': res['jac'],
#     202      'task': res['message'],
#     203      'funcalls': res['nfev'],
#     204      'nit': res['nit'],
#     205      'warnflag': res['status']}
#     206 f = res['fun']
#
# File C:\ProgramData\anaconda3\Lib\site-packages\scipy\optimize\_lbfgsb_py.py:361, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     355 task_str = task.tobytes()
#     356 if task_str.startswith(b'FG'):
#     357     # The minimization routine wants f and g at the current x.
#     358     # Note that interruptions due to maxfun are postponed
#     359     # until the completion of the current minimization iteration.
#     360     # Overwrite f and g:
# --> 361     f, g = func_and_grad(x)
#     362 elif task_str.startswith(b'NEW_X'):
#     363     # new iteration
#     364     n_iterations += 1
#
# File C:\ProgramData\anaconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:286, in ScalarFunction.fun_and_grad(self, x)
#     284     self._update_x_impl(x)
#     285 self._update_fun()
# --> 286 self._update_grad()
#     287 return self.f, self.g
#
# File C:\ProgramData\anaconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:256, in ScalarFunction._update_grad(self)
#     254 def _update_grad(self):
#     255     if not self.g_updated:
# --> 256         self._update_grad_impl()
#     257         self.g_updated = True
#
# File C:\ProgramData\anaconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:173, in ScalarFunction.__init__.<locals>.update_grad()
#     171 self._update_fun()
#     172 self.ngev += 1
# --> 173 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     174                            **finite_diff_options)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\scipy\optimize\_numdiff.py:505, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     502     use_one_sided = False
#     504 if sparsity is None:
# --> 505     return _dense_difference(fun_wrapped, x0, f0, h,
#     506                              use_one_sided, method)
#     507 else:
#     508     if not issparse(sparsity) and len(sparsity) == 2:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\scipy\optimize\_numdiff.py:576, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     574     x = x0 + h_vecs[i]
#     575     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 576     df = fun(x) - f0
#     577 elif method == '3-point' and use_one_sided[i]:
#     578     x1 = x0 + h_vecs[i]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\scipy\optimize\_numdiff.py:456, in approx_derivative.<locals>.fun_wrapped(x)
#     455 def fun_wrapped(x):
# --> 456     f = np.atleast_1d(fun(x, *args, **kwargs))
#     457     if f.ndim > 1:
#     458         raise RuntimeError("`fun` return value has "
#     459                            "more than 1 dimension.")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:534, in LikelihoodModel.fit.<locals>.f(params, *args)
#     533 def f(params, *args):
# --> 534     return -self.loglike(params, *args) / nobs
#
# File C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:933, in MLEModel.loglike(self, params, *args, **kwargs)
#     927 transformed, includes_fixed, complex_step, kwargs = _handle_args(
#     928     MLEModel._loglike_param_names, MLEModel._loglike_param_defaults,
#     929     *args, **kwargs)
#     931 params = self.handle_params(params, transformed=transformed,
#     932                             includes_fixed=includes_fixed)
# --> 933 self.update(params, transformed=True, includes_fixed=True,
#     934             complex_step=complex_step)
#     936 if complex_step:
#     937     kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#
# File C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1644, in SARIMAX.update(self, params, transformed, includes_fixed, complex_step)
#    1639 # Observation intercept
#    1640 # Exogenous data with MLE estimation of parameters enters through a
#    1641 # time-varying observation intercept (is equivalent to simply
#    1642 # subtracting it out of the endogenous variable first)
#    1643 if self.mle_regression:
# -> 1644     self.ssm['obs_intercept'] = np.dot(self.exog, params_exog)[None, :]
#    1646 # State intercept (Harvey) or additional observation intercept
#    1647 # (Hamilton)
#    1648 # SARIMA trend enters through the a time-varying state intercept,
#    1649 # associated with the first row of the stationary component of the
#    1650 # state vector (i.e. the first element of the state vector following
#    1651 # any differencing elements)
#    1652 if self._k_trend > 0:
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# #### visualize grid search results

# %%
res_sorted = pd.DataFrame(res, columns=['p', 'd', 'q', 'P', 'D', 'Q', 'AIC','BIC', 'MAE']).sort_values('MAE', ascending=True)
res_sorted.head(10)visualize_prediction
# Out:
#     p  d  q  P  D  Q           AIC           BIC       MAE
# 29  3  1  4  0  1  2 -15256.008007 -14479.136368  0.046048
# 35  3  1  4  2  1  2 -15256.729774 -14467.526840  0.046306
# 32  3  1  4  1  1  2 -15237.662623 -14454.625336  0.047357
# 38  3  1  5  0  1  2 -15247.370934 -14464.333648  0.047902
# 41  3  1  5  1  1  2 -15231.053172 -14441.850237  0.047939
# 44  3  1  5  2  1  2 -15245.067942 -14449.699359  0.048121
# 2   3  1  1  0  1  2 -15123.675063 -14365.300368  0.048453
# 31  3  1  4  1  1  1 -14999.078307 -14222.206668  0.048699
# 8   3  1  1  2  1  2 -15127.881136 -14357.175145  0.049007
# 28  3  1  4  0  1  1 -15101.765504 -14331.059514  0.049628

# %%
mae = np.mean(np.abs(model_fit.resid))
print('MAE: %.3f' % mae)
# Out:
# MAE: 0.022

# %% [markdown]
# ## Start Model Training

# %%
# %%time
# Fit the model without including val data
model_old = SARIMAX(y, exog=x, order=(1,1,1))
model_fit_old = model.fit(disp=False)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# CPU times: total: 5min 34s
# Wall time: 46 s

# %%
print(model_fit_old.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3543
# Model:               SARIMAX(1, 0, 1)   Log Likelihood                7464.984
# Date:                Sun, 10 Sep 2023   AIC                         -14697.969
# Time:                        22:16:46   BIC                         -13981.932
# Sample:                             0   HQIC                        -14442.583
#                                - 3543
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1041      0.010    -10.511      0.000      -0.123      -0.085
# x1            -0.0423      0.016     -2.669      0.008      -0.073      -0.011
# x2            -0.0294      0.006     -4.555      0.000      -0.042      -0.017
# x3             0.0002      0.001      0.192      0.848      -0.001       0.002
# x4            -0.0060      0.002     -3.199      0.001      -0.010      -0.002
# x5            -0.0529      0.018     -2.885      0.004      -0.089      -0.017
# x6            -0.0023      0.001     -2.245      0.025      -0.004      -0.000
# x7            -0.0014      0.001     -1.117      0.264      -0.004       0.001
# x8            -0.0031      0.001     -3.011      0.003      -0.005      -0.001
# x9            -0.0016      0.006     -0.267      0.789      -0.013       0.010
# x10            0.0501      0.009      5.460      0.000       0.032       0.068
# x11           -0.0003      0.005     -0.053      0.958      -0.011       0.010
0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                  82.02   Jarque-Bera (JB):               734.25
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.92   Skew:                             0.23
# Prob(H) (two-sided):                  0.14   Kurtosis:                         5.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.91e+17. Standard errors may be unstable.

# %%
mae = np.mean(np.abs(model_fit_old.resid))
print('MAE: %.3f' % mae)
# Out:
# MAE: 0.022

# %%
forecast = model_fit_old.forecast(steps = len(x_vals),exog = x_vals)
y_hat = forecast.reshape(forecast.shape[0], -1)

#visualize predication 
def visualize_prediction(y_pred, y_true, index):
    results = np.concatenate((y_pred, y_true), axis=1)
    df_res = pd.DataFrame(results, columns=["Pred", "Val"]) 
    df_res.index = index
    fig, ax = plt.subplots(figsize = (15,5))
    sns.lineplot(data=df_res)
    ax.set_title('CF_WS Prediction on Test Data', fontdict={'fontsize':16, 'fontweight':'bold'})
    ax.set_xlabel( "Time" , fontdict= { 'fontsize': 14, 'fontweight':'bold'})
    ax.set_ylabel( "CF" , fontdict= { 'fontsize': 14, 'fontweight':'bold'})

    
    
# output MAE
print(f'validation data MAE from sklearn mae metrics: {np.mean(abs(y_hat - y_vals)):.3f}')
visualize_prediction(y_hat, y_vals, df_train.index[-len(x_val):])
# Out:
# validation data MAE from sklearn mae metrics: 0.042

# %% [markdown]
# ### Process Test Data

# %%
## process data
x_test = df_test.reset_index(drop=True)
x_test = sm.add_constant(x_test)
x_test.head()
x_test = x_test.drop('CF', axis=1)

# %%
# last_train = train.iloc[len(train)-1].name
first_predict = x_test.iloc[0].name
print(x_test.shape)
x_test = (sm.add_constant(x_test).loc[first_predict:])
print(x_test.shape)
# x_test_arr = x_test.values
forecast = model_fit.forecast(steps = len(x_test),exog = x_test)
# print(forecast,len(forecast),len(x_test))

y_hat_test = forecast.reshape(forecast.shape[0], -1)

#visualize predication 
## Prepare dataframe
results = y_hat_test
# results = np.concatenate((y_hat), axis=1)
df_res = pd.DataFrame(results, columns=["trained by x_train data"]) 
## Set figure size
fig, ax = plt.subplots(figsize = (8,4))
# Plot the curve
sns.lineplot(data=df_res)
ax.set_title('CF_WS Prediction on Test Data', fontdict={'fontsize':16, 'fontweight':'bold'})
# Set label for x-axis
ax.set_xlabel( "Time" , fontdict= { 'fontsize': 14, 'fontweight':'bold'})
# Set label for y-axis
ax.set_ylabel( "CF" , fontdict= { 'fontsize': 14, 'fontweight':'bold'})
# Out:
# (93, 113)
# (93, 113)
# Text(0, 0.5, 'CF')

# %% [markdown]
# ## Diagnostics Analysis

# %%
arima_res = model_fit
arima_res.plot_diagnostics(figsize=(10,6))
plt.show()

# %% [markdown]
# ##### Standardized residual: Since the residuals look like random parttern,  it indicates a good model. Histogram plus kde estimate: The histogram shows the measured distribution of the residuals (orange line)  is close to a normal distribution. The  normal Q-Q:  indicates a normal distribution of the residuals. This is a good model. ACF plot also verifies normality check.
